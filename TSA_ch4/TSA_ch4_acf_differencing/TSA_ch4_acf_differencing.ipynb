# %% [markdown]
# # TSA Chapter 4: ACF Before/After Differencing
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QuantLet/TSA/blob/main/TSA_ch4/TSA_ch4_acf_differencing/TSA_ch4_acf_differencing.ipynb)
#
# ACF comparison: original vs seasonal+regular differencing.

# %%
# !pip install numpy pandas matplotlib statsmodels -q

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import acf, pacf
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %%
import os
COLORS = {'blue': '#1A3A6E', 'red': '#DC3545', 'green': '#2E7D32', 'orange': '#E67E22', 'gray': '#666666', 'purple': '#8E44AD'}
BLUE, RED, GREEN, ORANGE, GRAY, PURPLE = COLORS['blue'], COLORS['red'], COLORS['green'], COLORS['orange'], COLORS['gray'], COLORS['purple']

plt.rcParams.update({
    'figure.facecolor': 'none', 'axes.facecolor': 'none', 'savefig.facecolor': 'none',
    'savefig.transparent': True, 'axes.spines.top': False, 'axes.spines.right': False,
    'axes.grid': False, 'font.size': 10, 'axes.titlesize': 12, 'axes.labelsize': 10,
    'xtick.labelsize': 9, 'ytick.labelsize': 9, 'legend.fontsize': 9, 'figure.dpi': 150,
    'lines.linewidth': 1.2, 'axes.linewidth': 0.6, 'legend.facecolor': 'none',
    'legend.framealpha': 0, 'legend.edgecolor': 'none',
})

def save_chart(fig, name):
    fig.savefig(f'{name}.pdf', bbox_inches='tight', transparent=True, dpi=150)
    fig.savefig(f'{name}.png', bbox_inches='tight', transparent=True, dpi=150)
    print(f'Saved: {name}')

# %%
# Load airline passengers
data = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv',
                    parse_dates=['Month'], index_col='Month')
passengers = data['Passengers']
passengers.index.freq = 'MS'
log_passengers = np.log(passengers)

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
acf_orig = acf(log_passengers, nlags=36)
axes[0].bar(range(len(acf_orig)), acf_orig, color=BLUE, width=0.5)
axes[0].set_title('ACF: Log Passengers (Slow Decay)', fontweight='bold')
diff_both = log_passengers.diff().diff(12).dropna()
acf_diff = acf(diff_both, nlags=24)
axes[1].bar(range(len(acf_diff)), acf_diff, color=GREEN, width=0.5)
ci = 1.96 / np.sqrt(len(diff_both))
axes[1].axhline(y=ci, color=GRAY, ls='--'); axes[1].axhline(y=-ci, color=GRAY, ls='--')
axes[1].set_title('ACF: After Both Differences', fontweight='bold')
plt.tight_layout(); save_chart(fig, 'ch4_acf_differencing'); plt.show()
