# %% [markdown]
# # TSA Chapter 4: Quiz - Common Seasonal Periods
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QuantLet/TSA/blob/main/TSA_ch4/TSA_ch4_quiz1_seasonal_periods/TSA_ch4_quiz1_seasonal_periods.ipynb)
#
# Monthly (s=12), quarterly (s=4), weekly (s=52), daily (s=7).

# %%
# !pip install numpy pandas matplotlib statsmodels -q

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import acf, pacf
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %%
import os
COLORS = {'blue': '#1A3A6E', 'red': '#DC3545', 'green': '#2E7D32', 'orange': '#E67E22', 'gray': '#666666', 'purple': '#8E44AD'}
BLUE, RED, GREEN, ORANGE, GRAY, PURPLE = COLORS['blue'], COLORS['red'], COLORS['green'], COLORS['orange'], COLORS['gray'], COLORS['purple']

plt.rcParams.update({
    'figure.facecolor': 'none', 'axes.facecolor': 'none', 'savefig.facecolor': 'none',
    'savefig.transparent': True, 'axes.spines.top': False, 'axes.spines.right': False,
    'axes.grid': False, 'font.size': 10, 'axes.titlesize': 12, 'axes.labelsize': 10,
    'xtick.labelsize': 9, 'ytick.labelsize': 9, 'legend.fontsize': 9, 'figure.dpi': 150,
    'lines.linewidth': 1.2, 'axes.linewidth': 0.6, 'legend.facecolor': 'none',
    'legend.framealpha': 0, 'legend.edgecolor': 'none',
})

def save_chart(fig, name):
    fig.savefig(f'{name}.pdf', bbox_inches='tight', transparent=True, dpi=150)
    fig.savefig(f'{name}.png', bbox_inches='tight', transparent=True, dpi=150)
    print(f'Saved: {name}')

# %%
# Load airline passengers
data = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv',
                    parse_dates=['Month'], index_col='Month')
passengers = data['Passengers']
passengers.index.freq = 'MS'
log_passengers = np.log(passengers)

# %%
np.random.seed(42)
fig, axes = plt.subplots(2, 2, figsize=(12, 7))
t1 = np.arange(72); axes[0,0].plot(pd.date_range('2018-01-01', periods=72, freq='MS'), 50+15*np.sin(2*np.pi*t1/12)+np.random.normal(0,3,72), color=BLUE, lw=1); axes[0,0].set_title('Monthly: s = 12', fontweight='bold')
t2 = np.arange(40); axes[0,1].plot(pd.date_range('2014-01-01', periods=40, freq='QS'), 30+8*np.sin(2*np.pi*t2/4)+np.random.normal(0,1.5,40), color=GREEN, lw=1); axes[0,1].set_title('Quarterly: s = 4', fontweight='bold')
t3 = np.arange(156); axes[1,0].plot(pd.date_range('2021-01-04', periods=156, freq='W-MON'), 100+20*np.sin(2*np.pi*t3/52)+np.random.normal(0,5,156), color=ORANGE, lw=0.8); axes[1,0].set_title('Weekly: s = 52', fontweight='bold')
t4 = np.arange(91); axes[1,1].plot(pd.date_range('2023-07-01', periods=91, freq='D'), 50+10*np.sin(2*np.pi*t4/7)+np.random.normal(0,3,91), color=PURPLE, lw=1); axes[1,1].set_title('Daily: s = 7', fontweight='bold')
plt.tight_layout(); save_chart(fig, 'ch4_quiz1_seasonal_periods'); plt.show()
