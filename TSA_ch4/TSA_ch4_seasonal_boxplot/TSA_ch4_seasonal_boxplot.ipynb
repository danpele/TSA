# %% [markdown]
# # TSA Chapter 4: Seasonal Boxplot by Month
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QuantLet/TSA/blob/main/TSA_ch4/TSA_ch4_seasonal_boxplot/TSA_ch4_seasonal_boxplot.ipynb)
#
# Monthly boxplot of airline passengers colored by season.

# %%
# !pip install numpy pandas matplotlib statsmodels -q

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import acf, pacf
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# %%
import os
COLORS = {'blue': '#1A3A6E', 'red': '#DC3545', 'green': '#2E7D32', 'orange': '#E67E22', 'gray': '#666666', 'purple': '#8E44AD'}
BLUE, RED, GREEN, ORANGE, GRAY, PURPLE = COLORS['blue'], COLORS['red'], COLORS['green'], COLORS['orange'], COLORS['gray'], COLORS['purple']

plt.rcParams.update({
    'figure.facecolor': 'none', 'axes.facecolor': 'none', 'savefig.facecolor': 'none',
    'savefig.transparent': True, 'axes.spines.top': False, 'axes.spines.right': False,
    'axes.grid': False, 'font.size': 10, 'axes.titlesize': 12, 'axes.labelsize': 10,
    'xtick.labelsize': 9, 'ytick.labelsize': 9, 'legend.fontsize': 9, 'figure.dpi': 150,
    'lines.linewidth': 1.2, 'axes.linewidth': 0.6, 'legend.facecolor': 'none',
    'legend.framealpha': 0, 'legend.edgecolor': 'none',
})

def save_chart(fig, name):
    fig.savefig(f'{name}.pdf', bbox_inches='tight', transparent=True, dpi=150)
    fig.savefig(f'{name}.png', bbox_inches='tight', transparent=True, dpi=150)
    print(f'Saved: {name}')

# %%
# Load airline passengers
data = pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv',
                    parse_dates=['Month'], index_col='Month')
passengers = data['Passengers']
passengers.index.freq = 'MS'
log_passengers = np.log(passengers)

# %%
from matplotlib.patches import Patch
fig, ax = plt.subplots(figsize=(10, 4))
data_by_month = [passengers[passengers.index.month == m].values for m in range(1, 13)]
bp = ax.boxplot(data_by_month, labels=['J','F','M','A','M','J','J','A','S','O','N','D'], patch_artist=True, medianprops=dict(color=RED, lw=2))
season_colors = [BLUE,BLUE,GREEN,GREEN,GREEN,ORANGE,ORANGE,ORANGE,PURPLE,PURPLE,PURPLE,BLUE]
for patch, c in zip(bp['boxes'], season_colors): patch.set_facecolor(c); patch.set_alpha(0.4)
ax.set_title('Seasonal Boxplot: Airline Passengers', fontweight='bold')
plt.tight_layout(); save_chart(fig, 'ch4_seasonal_boxplot'); plt.show()
